# %% [markdown]
# # Data Analytics for Customer Shopping Trend

# %% [markdown]
# The Customer Shopping Preferences Dataset offers valuable insights into consumer behavior and purchasing patterns. Understanding customer preferences and trends is critical for businesses to tailor their products, marketing strategies, and overall customer experience. This dataset captures a wide range of customer attributes including age, gender, purchase history, preferred payment methods, frequency of purchases, and more. Analyzing this data can help businesses make informed decisions, optimize product offerings, and enhance customer satisfaction. The dataset stands as a valuable resource for businesses aiming to align their strategies with customer needs and preferences. It's important to note that this dataset is a Synthetic Dataset Created for Beginners to learn more about Data Analysis and Machine Learning

# %% [markdown]
# This dataset encompasses various features related to customer shopping preferences, gathering essential information for businesses seeking to enhance their understanding of their customer base. The features include customer age, gender, purchase amount, preferred payment methods, frequency of purchases, and feedback ratings. Additionally, data on the type of items purchased, shopping frequency, preferred shopping seasons, and interactions with promotional offers is included. With a collection of 3900 records, this dataset serves as a foundation for businesses looking to apply data-driven insights for better decision-making and customer-centric strategies.

# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Reading dataset with read CSV method from pandas

df = pd.read_csv('shopping_trends.csv')

# %%
# Checking the Dataset by calling df

df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# Descriptive Stats | Data Information

df.describe() # It will give us a short summary about the data.
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# - NOTE : As we can see we only have 5 numeric columns

# %%
# In INfoormation we are able to get the data types and null values idea

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
# Checking Null Values

df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
# Delete or drop unneccessaary columns or data.

df.drop('Customer ID',axis=1,inplace=True)

# %%
df
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
# Most age group 

df.Age.value_counts()
# Out:
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 50    83
# 54    83
# 27    83
# 62    83
# 32    82
# 19    81
# 58    81
# 42    80
# 43    79
# 28    79
# 31    79
# 37    77
# 46    76
# 29    76
# 68    75
# 59    75
# 63    75
# 56    74
# 36    74
# 55    73
# 52    73
# 64    73
# 35    72
# 51    72
# 65    72
# 40    72
# 45    72
# 47    71
# 66    71
# 30    71
# 23    71
# 38    70
# 53    70
# 18    69
# 21    69
# 26    69
# 34    68
# 48    68
# 24    68
# 39    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: Age, dtype: int64

# %%
# Which item has been sold the most

df['Item Purchased'].value_counts()
# Out:
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: Item Purchased, dtype: int64

# %%
df
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
# Checking Location categorywise

df.Location.value_counts()
# Out:
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# Nebraska          87
# New York          87
# Nevada            87
# Maryland          86
# Delaware          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# Missouri          81
# West Virginia     81
# New Mexico        81
# Mississippi       80
# Indiana           79
# Georgia           79
# Kentucky          79
# Arkansas          79
# North Carolina    78
# Connecticut       78
# Virginia          77
# Ohio              77
# Tennessee         77
# Texas             77
# Maine             77
# South Carolina    76
# Colorado          75
# Oklahoma          75
# Wisconsin         75
# Oregon            74
# Pennsylvania      74
# Washington        73
# Michigan          73
# Alaska            72
# Massachusetts     72
# Wyoming           71
# Utah              71
# New Hampshire     71
# South Dakota      70
# ...

# %%
# What is the average age of customers in the dataset ?
# What is the most common item purchased ?
# What is the total purchase amount for each category ?
# What is the most common payment method used by customers ?
# What is the median purchase amount (USD) ?
# How many customers have opted for the Subscription ?
# What is the most common season for purchases ?

# %%
# What is the average age of customers in the dataset ?

df.Age.mean()
# Out:
# 44.06846153846154

# %%
# What is the most common item purchased ?

# This question can be solved by 2 methods 1. Value Counts 2. Mode

df['Item Purchased'].value_counts().head()
# Out:
# Blouse     171
# Jewelry    171
# Pants      171
# Shirt      169
# Dress      166
# Name: Item Purchased, dtype: int64

# %%
# What is the total purchase amount for each category ?

df.Category.value_counts()
# Out:
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: Category, dtype: int64

# %%
# Using Groupby Method

df.groupby('Category')['Purchase Amount (USD)'].sum()
# Out:
# Category
# Accessories     74200
# Clothing       104264
# Footwear        36093
# Outerwear       18524
# Name: Purchase Amount (USD), dtype: int64

# %%
# What is the most common payment method used by customers ?

df['Payment Method'].value_counts()
# Out:
# Credit Card      696
# Venmo            653
# Cash             648
# PayPal           638
# Debit Card       633
# Bank Transfer    632
# Name: Payment Method, dtype: int64

# %%
# What is the median purchase amount (USD) ?

df['Purchase Amount (USD)'].median()
# Out:
# 60.0

# %%
# How many customers have opted for the Subscription ?

df['Subscription Status'].value_counts()
# Out:
# No     2847
# Yes    1053
# Name: Subscription Status, dtype: int64

# %%
# What is the most common season for purchases ?

df.Season.value_counts()
# Out:
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: Season, dtype: int64

# %%
df
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
# Countplot for Gender to check how many males and females

sns.countplot(df.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
# Distribution PLot for age

plt.figure(figsize=(20,8))
sns.histplot(df.Age,kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
# BAr PLot to check what category we sold the most

df.Category.value_counts()
# Out:
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(20,8))
df.Category.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# ...

# %%
# Create a bar plot for Item Purchased

plt.figure(figsize=(20,12))
df['Item Purchased'].value_counts().sort_values().plot(kind='barh',color=sns.color_palette('tab20'))
# Out:
# <AxesSubplot:>

# %%
# In Size column we can change the text from short to long
# We can chane L to Large, M to Medium and S to Small

df.Size.value_counts()
# Out:
# M     1755
# L     1053
# S      663
# XL     429
# Name: Size, dtype: int64

# %%
df.Size = df.Size.replace('L','Large')
df.Size = df.Size.replace('M','Medium')
df.Size = df.Size.replace('S','Small')
df.Size = df.Size.replace('XL','Xtra_Large')

# %%
df
# Out:
#       Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0      55    Male         Blouse     Clothing                     53
# 1      19    Male        Sweater     Clothing                     64
# 2      50    Male          Jeans     Clothing                     73
# 3      21    Male        Sandals     Footwear                     90
# 4      45    Male         Blouse     Clothing                     49
# ...   ...     ...            ...          ...                    ...
# 3895   40  Female         Hoodie     Clothing                     28
# 3896   52  Female       Backpack  Accessories                     49
# 3897   46  Female           Belt  Accessories                     33
# 3898   44  Female          Shoes     Footwear                     77
# 3899   52  Female        Handbag  Accessories                     81
#
#            Location    Size      Color  Season  Review Rating  \
# 0          Kentucky   Large       Gray  Winter            3.1
# ...

# %%
# Transaction according to pie chart

plt.figure(figsize=(10,9))

df['Payment Method'].value_counts().plot(kind='pie',legend=True,autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Payment Method'>

# %%
# Pie chart with shipping

plt.figure(figsize=(10,9))

df['Shipping Type'].value_counts().plot(kind='pie',legend=True,autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Shipping Type'>

# %%
# What is the average age of a customer.
# MAle and Female

df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    44.007212
# Male      44.097285
# Name: Age, dtype: float64
